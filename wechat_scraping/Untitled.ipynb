# %%
import pandas as pd

# %%
df = pd.read_csv("data/环球时报.csv")

# %%
df['content'].isna().sum() + (df['content'] == '').sum() + (df['content'].isnan()).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/y7/2k5vxcdj74b8rsyvc2psl2vc0000gn/T/ipykernel_84809/3192945306.py in ?()
# ----> 1 df['content'].isna().sum() + (df['content'] == '').sum() + (df['content'].isnan()).sum()
#
# /Applications/anaconda3/envs/python312/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'isnan'

# %%
df[df['content'].isna()]
# Out:
#         author                       title content  \
# 620        NaN                    孙杨复出首战夺冠     NaN
# 967         社评         维护全球金融稳定，美方应同中国相向而行     NaN
# 992        NaN  日媒紧盯：中国增多日本减少，这一指标发生“地壳变动”     NaN
# 1014       候华静       “我们是世界上最道德的国家，你听到了吗？”     NaN
# 1058       NaN              日本首相岸田将辞任，中方表态     NaN
# 1825      索炎琦等                  美国紧急向这里增兵！     NaN
# 2108       NaN                    中国人民银行宣布     NaN
# 2225  环球时报-环球网        美国和日本这个做法，已成为和平的新威胁！     NaN
# 2291       梁由之           这回反过来了？英国紧急向巴黎调派→     NaN
# 2421       NaN                 中方敦促美国立即停止！     NaN
# 2427       NaN            泽连斯基最新表态：必须尽快结束！     NaN
# 2841       NaN           突发！以军轰炸，“300多人死伤”     NaN
# 3059       NaN               习近平会见匈牙利总理欧尔班     NaN
# 3149       NaN                         NaN     NaN
# 3381       NaN                  中国代表三次回击美方     NaN
# 3765       NaN                 上海地铁发生持刀伤人案     NaN
#
#                                                    link      read    like  \
# ...

# %%
df[df['title'].str.contains("三甲", na=False)]
# Out:
#      author              title  \
# 1500    NaN       2024香港小姐三甲出炉
# 3347    NaN  三甲专家下班直播唱歌火了，本人发声
#
#                                                 content  \
# 1500  2\n0\n2\n4\n香\n港\n小\n姐\n三\n甲\n出\n炉\n！\n“\n翻\n版...
# 3347  中\n国\n共\n产\n党\n党\n内\n统\n计\n公\n报\n中\n共\n中\n央\n组...
#
#                                                    link     read   like  time  \
# 1500  http://mp.weixin.qq.com/s?__biz=MjM5MDk1NzQzMQ...  45875.0  259.0   NaN
# 3347  http://mp.weixin.qq.com/s?__biz=MjM5MDk1NzQzMQ...  70130.0  734.0   NaN
#
#                  pub_time          scrape_time
# 1500  2024-09-16 21:25:48  2024-09-19 11:07:56
# 3347  2024-06-29 23:26:01  2024-09-23 14:54:25
